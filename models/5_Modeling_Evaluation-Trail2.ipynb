# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score, f1_score, precision_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import xgboost as xgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Load SVD file
svd_file_path = "/Users/navyakalyani/Downloads/drug_project/svd_drug_pair_features.h5"

with h5py.File(svd_file_path, "r") as h5f:
    X_train = h5f["X_train"][:]
    y_train = h5f["y_train"][:]
    X_val = h5f["X_val"][:]
    y_val = h5f["y_val"][:]
    X_test = h5f["X_test"][:]
    y_test = h5f["y_test"][:]

# Checking the shapes
print(f"X_train shape: {X_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (626978, 200)
# X_val shape: (134353, 200)
# X_test shape: (134353, 200)

# %%
# Evaluation Metrics Functions
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def plot_roc_curve(y_true, y_pred, model_name):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic - {model_name}')
    plt.legend(loc="lower right")
    plt.show()

def print_classification_report(y_true, y_pred, model_name):
    print(f"Classification Report for {model_name}:\n")
    print(classification_report(y_true, y_pred))

def print_metrics(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)

    print(f"{model_name} - Accuracy: {accuracy:.4f}")
    print(f"{model_name} - F1 Score: {f1:.4f}")
    print(f"{model_name} - Precision: {precision:.4f}")

    plot_confusion_matrix(y_true, y_pred, model_name)
    plot_roc_curve(y_true, y_pred, model_name)
    print_classification_report(y_true, y_pred, model_name)

# %%
# Train and Evaluate Models

# 1. Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

print("\nRandom Forest Model Evaluation:")
print_metrics(y_test, rf_pred, "Random Forest")
# Out:
# Random Forest Model Evaluation:
# Random Forest - Accuracy: 0.6489
# Random Forest - F1 Score: 0.5901
# Random Forest - Precision: 0.7102
# Classification Report for Random Forest:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     67072
#            1       0.71      0.50      0.59     67281
#
#     accuracy                           0.65    134353
#    macro avg       0.66      0.65      0.64    134353
# weighted avg       0.66      0.65      0.64    134353

# %%
# 2. Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)
gb_pred = gb_model.predict(X_test)

print("\nGradient Boosting Model Evaluation:")
print_metrics(y_test, gb_pred, "Gradient Boosting")
# Out:
# Gradient Boosting Model Evaluation:
# Gradient Boosting - Accuracy: 0.6490
# Gradient Boosting - F1 Score: 0.5904
# Gradient Boosting - Precision: 0.7103
# Classification Report for Gradient Boosting:
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.79      0.69     67072
#            1       0.71      0.51      0.59     67281
#
#     accuracy                           0.65    134353
#    macro avg       0.66      0.65      0.64    134353
# weighted avg       0.66      0.65      0.64    134353

# %%
# 3. XGBoost Classifier
xgb_model = xgb.XGBClassifier(n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

print("\nXGBoost Model Evaluation:")
print_metrics(y_test, xgb_pred, "XGBoost")
# Out:
# XGBoost Model Evaluation:
# XGBoost - Accuracy: 0.6489
# XGBoost - F1 Score: 0.5901
# XGBoost - Precision: 0.7102
# Classification Report for XGBoost:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     67072
#            1       0.71      0.50      0.59     67281
#
#     accuracy                           0.65    134353
#    macro avg       0.66      0.65      0.64    134353
# weighted avg       0.66      0.65      0.64    134353

# %%
# Deep Learning Models

# 4. Simple Neural Network
def create_nn_model(input_dim):
    model = Sequential()
    model.add(Dense(128, input_dim=input_dim, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

nn_model = create_nn_model(X_train.shape[1])
nn_model.fit(X_train, y_train, epochs=20, batch_size=128, validation_data=(X_val, y_val), verbose=1)
nn_pred = (nn_model.predict(X_test) > 0.5).astype("int32")

print("\nNeural Network Model Evaluation:")
print_metrics(y_test, nn_pred, "Neural Network")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 4s 679us/step - accuracy: 0.5827 - loss: 0.6821 - val_accuracy: 0.6476 - val_loss: 0.6572
# Epoch 2/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 635us/step - accuracy: 0.6291 - loss: 0.6474 - val_accuracy: 0.6362 - val_loss: 0.6428
# Epoch 3/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 606us/step - accuracy: 0.6371 - loss: 0.6436 - val_accuracy: 0.6367 - val_loss: 0.6412
# Epoch 4/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 606us/step - accuracy: 0.6406 - loss: 0.6422 - val_accuracy: 0.6448 - val_loss: 0.6388
# Epoch 5/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 616us/step - accuracy: 0.6417 - loss: 0.6413 - val_accuracy: 0.6449 - val_loss: 0.6388
# Epoch 6/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 600us/step - accuracy: 0.6438 - loss: 0.6399 - val_accuracy: 0.6478 - val_loss: 0.6408
# Epoch 7/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 613us/step - accuracy: 0.6438 - loss: 0.6400 - val_accuracy: 0.6455 - val_loss: 0.6369
# Epoch 8/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 598us/step - accuracy: 0.6447 - loss: 0.6396 - val_accuracy: 0.6483 - val_loss: 0.6367
# Epoch 9/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 605us/step - accuracy: 0.6457 - loss: 0.6383 - val_accuracy: 0.6451 - val_loss: 0.6370
# Epoch 10/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 614us/step - accuracy: 0.6454 - loss: 0.6384 - val_accuracy: 0.6476 - val_loss: 0.6363
# Epoch 11/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 610us/step - accuracy: 0.6454 - loss: 0.6386 - val_accuracy: 0.6484 - val_loss: 0.6363
# Epoch 12/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 607us/step - accuracy: 0.6448 - loss: 0.6389 - val_accuracy: 0.6484 - val_loss: 0.6365
# Epoch 13/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 609us/step - accuracy: 0.6456 - loss: 0.6383 - val_accuracy: 0.6452 - val_loss: 0.6385
# Epoch 14/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 606us/step - accuracy: 0.6453 - loss: 0.6383 - val_accuracy: 0.6479 - val_loss: 0.6368
# Epoch 15/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 597us/step - accuracy: 0.6471 - loss: 0.6374 - val_accuracy: 0.6454 - val_loss: 0.6379
# Epoch 16/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 607us/step - accuracy: 0.6452 - loss: 0.6388 - val_accuracy: 0.6479 - val_loss: 0.6358
# Epoch 17/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 597us/step - accuracy: 0.6454 - loss: 0.6384 - val_accuracy: 0.6489 - val_loss: 0.6355
# Epoch 18/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 634us/step - accuracy: 0.6458 - loss: 0.6374 - val_accuracy: 0.6489 - val_loss: 0.6358
# Epoch 19/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 606us/step - accuracy: 0.6465 - loss: 0.6367 - val_accuracy: 0.6489 - val_loss: 0.6360
# Epoch 20/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 598us/step - accuracy: 0.6462 - loss: 0.6373 - val_accuracy: 0.6489 - val_loss: 0.6353
# 4199/4199 ━━━━━━━━━━━━━━━━━━━━ 1s 216us/step
#
# Neural Network Model Evaluation:
# Neural Network - Accuracy: 0.6476
# Neural Network - F1 Score: 0.5899
# Neural Network - Precision: 0.7069
# Classification Report for Neural Network:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     67072
#            1       0.71      0.51      0.59     67281
#
#     accuracy                           0.65    134353
#    macro avg       0.66      0.65      0.64    134353
# weighted avg       0.66      0.65      0.64    134353

# %%
# 5. Advanced Deep Learning Model (CNN-based)
def create_cnn_model(input_shape):
    model = Sequential()
    model.add(Dense(128, input_dim=input_shape[1], activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

cnn_model = create_cnn_model(X_train.shape)
cnn_model.fit(X_train, y_train, epochs=20, batch_size=128, validation_data=(X_val, y_val), verbose=1)
cnn_pred = (cnn_model.predict(X_test) > 0.5).astype("int32")

print("\nCNN Model Evaluation:")
print_metrics(y_test, cnn_pred, "CNN")
# Out:
# Epoch 1/20
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 633us/step - accuracy: 0.5827 - loss: 0.6862 - val_accuracy: 0.6269 - val_loss: 0.6471
# Epoch 2/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 602us/step - accuracy: 0.6291 - loss: 0.6469 - val_accuracy: 0.6360 - val_loss: 0.6417
# Epoch 3/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 615us/step - accuracy: 0.6355 - loss: 0.6444 - val_accuracy: 0.6400 - val_loss: 0.6398
# Epoch 4/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 601us/step - accuracy: 0.6412 - loss: 0.6421 - val_accuracy: 0.6448 - val_loss: 0.6391
# Epoch 5/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 663us/step - accuracy: 0.6415 - loss: 0.6408 - val_accuracy: 0.6445 - val_loss: 0.6386
# Epoch 6/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 606us/step - accuracy: 0.6429 - loss: 0.6406 - val_accuracy: 0.6405 - val_loss: 0.6402
# Epoch 7/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 616us/step - accuracy: 0.6444 - loss: 0.6403 - val_accuracy: 0.6451 - val_loss: 0.6374
# Epoch 8/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 605us/step - accuracy: 0.6432 - loss: 0.6398 - val_accuracy: 0.6478 - val_loss: 0.6386
# Epoch 9/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 613us/step - accuracy: 0.6433 - loss: 0.6398 - val_accuracy: 0.6476 - val_loss: 0.6370
# Epoch 10/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 608us/step - accuracy: 0.6452 - loss: 0.6387 - val_accuracy: 0.6478 - val_loss: 0.6391
# Epoch 11/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 611us/step - accuracy: 0.6450 - loss: 0.6385 - val_accuracy: 0.6480 - val_loss: 0.6365
# Epoch 12/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 607us/step - accuracy: 0.6455 - loss: 0.6384 - val_accuracy: 0.6451 - val_loss: 0.6365
# Epoch 13/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 630us/step - accuracy: 0.6459 - loss: 0.6382 - val_accuracy: 0.6482 - val_loss: 0.6368
# Epoch 14/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 634us/step - accuracy: 0.6451 - loss: 0.6384 - val_accuracy: 0.6487 - val_loss: 0.6355
# Epoch 15/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 595us/step - accuracy: 0.6451 - loss: 0.6383 - val_accuracy: 0.6480 - val_loss: 0.6357
# Epoch 16/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 608us/step - accuracy: 0.6463 - loss: 0.6373 - val_accuracy: 0.6483 - val_loss: 0.6353
# Epoch 17/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 627us/step - accuracy: 0.6461 - loss: 0.6376 - val_accuracy: 0.6460 - val_loss: 0.6361
# Epoch 18/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 630us/step - accuracy: 0.6461 - loss: 0.6379 - val_accuracy: 0.6493 - val_loss: 0.6345
# Epoch 19/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 620us/step - accuracy: 0.6476 - loss: 0.6365 - val_accuracy: 0.6460 - val_loss: 0.6356
# Epoch 20/20
# 4899/4899 ━━━━━━━━━━━━━━━━━━━━ 3s 623us/step - accuracy: 0.6465 - loss: 0.6372 - val_accuracy: 0.6457 - val_loss: 0.6356
# 4199/4199 ━━━━━━━━━━━━━━━━━━━━ 1s 220us/step
#
# CNN Model Evaluation:
# CNN - Accuracy: 0.6448
# CNN - F1 Score: 0.5793
# CNN - Precision: 0.7118
# Classification Report for CNN:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.80      0.69     67072
#            1       0.71      0.49      0.58     67281
#
#     accuracy                           0.64    134353
#    macro avg       0.66      0.65      0.64    134353
# weighted avg       0.66      0.64      0.64    134353

# %%
# Final Decision - Best Model
# Based on the evaluation metrics (accuracy, F1 score, precision), select the best model

models = {
    "Random Forest": rf_model,
    "Gradient Boosting": gb_model,
    "XGBoost": xgb_model,
    "Neural Network": nn_model,
    "CNN": cnn_model
}

# Evaluate the accuracy of each model
model_accuracies = {}
model_accuracies['Random Forest'] = accuracy_score(y_test, rf_pred)
model_accuracies['Gradient Boosting'] = accuracy_score(y_test, gb_pred)
model_accuracies['XGBoost'] = accuracy_score(y_test, xgb_pred)
model_accuracies['Neural Network'] = accuracy_score(y_test, nn_pred)
model_accuracies['CNN'] = accuracy_score(y_test, cnn_pred)

# Print the best model
best_model_name = max(model_accuracies, key=model_accuracies.get)
print(f"\nBest Model for the Dataset: {best_model_name} with Accuracy: {model_accuracies[best_model_name]:.4f}")
# Out:
# Best Model for the Dataset: Gradient Boosting with Accuracy: 0.6490

# %% [markdown]
# ## Improvements

# %% [markdown]
# Steps in Code:
#
# *   Apply SMOTE for Class Imbalance.
# *   Hyperparameter Tuning using GridSearchCV.

# %%
import numpy as np
import h5py
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    f1_score,
    roc_auc_score,
    accuracy_score,
    precision_recall_curve,
    roc_curve
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Apply SMOTE to balance the classes
print("Applying SMOTE to balance the classes...")
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)
print(f"After SMOTE - X_train_balanced: {X_train_balanced.shape}, y_train_balanced: {y_train_balanced.shape}")
# Out:
# Applying SMOTE to balance the classes...
# After SMOTE - X_train_balanced: (628472, 200), y_train_balanced: (628472,)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Visualize the class distribution before applying SMOTE
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x=y_train)
plt.title('Class Distribution Before SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')

# Visualize the class distribution after applying SMOTE
plt.subplot(1, 2, 2)
sns.countplot(x=y_train_balanced)
plt.title('Class Distribution After SMOTE')
plt.xlabel('Class')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# Print the class distribution
print(f"Before SMOTE: {Counter(y_train)}")
print(f"After SMOTE: {Counter(y_train_balanced)}")
# Out:
# Before SMOTE: Counter({1: 314236, 0: 312742})
# After SMOTE: Counter({0: 314236, 1: 314236})

# %% [markdown]
# ## Hyperparameter Tuning for Random Forest, Gradient Boosting, and XGBoost

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Use smaller dataset for faster execution
X_train_subset = X_train_balanced[:150000]
y_train_subset = y_train_balanced[:150000]
X_test_subset = X_test[:50000]
y_test_subset = y_test[:50000]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluation Metrics
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def plot_roc_curve(y_true, y_pred, model_name):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic - {model_name}')
    plt.legend(loc="lower right")
    plt.show()

def print_metrics(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    print(f"{model_name} - Accuracy: {accuracy:.4f}")
    print(f"\nClassification Report for {model_name}:\n{classification_report(y_true, y_pred)}")
    plot_confusion_matrix(y_true, y_pred, model_name)
    plot_roc_curve(y_true, y_pred, model_name)

# %%
# Random Forest Tuning
rf_param_grid = {
    "n_estimators": [150, 200],
    "max_depth": [5, 20],
    "min_samples_split": [2, 3],
    "min_samples_leaf": [1, 2],
}

print("\nTuning Random Forest...")
rf = RandomForestClassifier(random_state=42)
rf_grid = GridSearchCV(rf, param_grid=rf_param_grid, scoring="accuracy", cv=2, verbose=2, n_jobs=-1)
rf_grid.fit(X_train_subset, y_train_subset)

rf_best = rf_grid.best_estimator_
print(f"Random Forest Best Params: {rf_grid.best_params_}")
rf_pred = rf_best.predict(X_test_subset)
print_metrics(y_test_subset, rf_pred, "Random Forest")
# Out:
# Tuning Random Forest...
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# Random Forest Best Params: {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}
# Random Forest - Accuracy: 0.6473
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     24917
#            1       0.71      0.50      0.59     25083
#
#     accuracy                           0.65     50000
#    macro avg       0.66      0.65      0.64     50000
# weighted avg       0.66      0.65      0.64     50000

# %%
# Gradient Boosting Tuning
gb_param_grid = {
    "n_estimators": [250, 500],
    "learning_rate": [0.02, 0.3],
    "max_depth": [3, 5]
}

print("\nTuning Gradient Boosting...")
gb = GradientBoostingClassifier(random_state=42)
gb_grid = GridSearchCV(gb, param_grid=gb_param_grid, scoring="accuracy", cv=2, verbose=2, n_jobs=-1)
gb_grid.fit(X_train_subset, y_train_subset)

gb_best = gb_grid.best_estimator_
print(f"Gradient Boosting Best Params: {gb_grid.best_params_}")
gb_pred = gb_best.predict(X_test_subset)
print_metrics(y_test_subset, gb_pred, "Gradient Boosting")
# Out:
# Tuning Gradient Boosting...
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  30.8s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  27.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  56.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  31.9s
# [CV] END ..learning_rate=0.02, max_depth=5, n_estimators=500; total time=17.9min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=150; total time=  20.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  56.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=150; total time=  33.3s
# [CV] END ..learning_rate=0.02, max_depth=5, n_estimators=500; total time=18.2min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  24.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  28.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=150; total time=  41.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  46.0s
# [CV] END ..learning_rate=0.02, max_depth=5, n_estimators=250; total time= 8.3min
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=500; total time=11.3min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=3, n_estimators=150; total time=  24.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  27.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  56.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=150; total time=  32.0s
# [CV] END ..learning_rate=0.02, max_depth=5, n_estimators=250; total time= 8.6min
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=500; total time=11.1min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  30.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=150; total time=  22.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=150; total time=  41.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  46.9s
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=500; total time=11.5min
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=250; total time= 8.6min
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=3, n_estimators=150; total time=  23.8s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  21.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  39.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  39.7s
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=500; total time=11.5min
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=250; total time= 8.6min
# Gradient Boosting Best Params: {'learning_rate': 0.02, 'max_depth': 3, 'n_estimators': 250}
# Gradient Boosting - Accuracy: 0.6471
#
# Classification Report for Gradient Boosting:
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     24917
#            1       0.71      0.50      0.59     25083
#
#     accuracy                           0.65     50000
#    macro avg       0.66      0.65      0.64     50000
# weighted avg       0.66      0.65      0.64     50000

# %%
# XGBoost Tuning
xgb_param_grid = {
    "n_estimators": [300, 500],
    "learning_rate": [0.02, 0.3],
    "max_depth": [3, 5]
}

print("\nTuning XGBoost...")
xgb = XGBClassifier(random_state=42)
xgb_grid = GridSearchCV(xgb, param_grid=xgb_param_grid, scoring="accuracy", cv=2, verbose=2, n_jobs=-1)
xgb_grid.fit(X_train_subset, y_train_subset)

xgb_best = xgb_grid.best_estimator_
print(f"XGBoost Best Params: {xgb_grid.best_params_}")
xgb_pred = xgb_best.predict(X_test_subset)
print_metrics(y_test_subset, xgb_pred, "XGBoost")
# Out:
# Tuning XGBoost...
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# XGBoost Best Params: {'learning_rate': 0.02, 'max_depth': 5, 'n_estimators': 300}
# XGBoost - Accuracy: 0.6474
#
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69     24917
#            1       0.71      0.50      0.59     25083
#
#     accuracy                           0.65     50000
#    macro avg       0.66      0.65      0.64     50000
# weighted avg       0.66      0.65      0.64     50000

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

def create_nn_model():
    model = Sequential()
    model.add(Dense(256, input_dim=X_train_balanced.shape[1], activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.002), loss='binary_crossentropy', metrics=['accuracy'])
    return model

print("\nTraining Neural Network...")
nn_model = create_nn_model()
early_stopping = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
nn_history = nn_model.fit(X_train_balanced, y_train_balanced, epochs=25, batch_size=128, validation_data=(X_val, y_val), callbacks=[early_stopping], verbose=1)

# Evaluate
nn_pred = (nn_model.predict(X_test) > 0.5).astype("int32")
print_metrics(y_test, nn_pred, "Neural Network")
# Out:
# Training Neural Network...
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - accuracy: 0.6340 - loss: 0.6515 - val_accuracy: 0.4981 - val_loss: 0.9784
# Epoch 2/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6453 - loss: 0.6405 - val_accuracy: 0.5027 - val_loss: 0.9126
# Epoch 3/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6461 - loss: 0.6395 - val_accuracy: 0.5022 - val_loss: 2.8577
# Epoch 4/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6458 - loss: 0.6391 - val_accuracy: 0.4983 - val_loss: 2.7256
# Epoch 5/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6461 - loss: 0.6392 - val_accuracy: 0.4983 - val_loss: 4.6551
# Epoch 6/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6458 - loss: 0.6403 - val_accuracy: 0.4989 - val_loss: 0.6663
# Epoch 7/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6328 - loss: 0.6484 - val_accuracy: 0.5025 - val_loss: 3.4905
# Epoch 8/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6412 - loss: 0.6442 - val_accuracy: 0.4978 - val_loss: 0.8495
# Epoch 9/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6368 - loss: 0.6466 - val_accuracy: 0.5914 - val_loss: 0.7064
# Epoch 10/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6392 - loss: 0.6448 - val_accuracy: 0.4981 - val_loss: 1.6493
# Epoch 11/25
# 4910/4910 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step - accuracy: 0.6416 - loss: 0.6431 - val_accuracy: 0.4982 - val_loss: 0.6967
# 4199/4199 ━━━━━━━━━━━━━━━━━━━━ 1s 300us/step
# Neural Network - Accuracy: 0.5022
#
# Classification Report for Neural Network:
#               precision    recall  f1-score   support
#
#            0       0.94      0.00      0.01     67072
#            1       0.50      1.00      0.67     67281
#
#     accuracy                           0.50    134353
#    macro avg       0.72      0.50      0.34    134353
# weighted avg       0.72      0.50      0.34    134353

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Reshape Input for CNN
X_train_cnn = X_train_balanced.reshape(X_train_balanced.shape[0], X_train_balanced.shape[1], 1)
X_val_cnn = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)
X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print("\nStarting CNN Training...")

# Define CNN Model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=64, kernel_size=5, activation='relu', input_shape=(X_train_cnn.shape[1], 1)))  # Larger kernel size
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.2))  # Reduced dropout rate
cnn_model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))  # Added smaller kernel size
cnn_model.add(BatchNormalization())
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Dropout(0.3))
cnn_model.add(Flatten())
cnn_model.add(Dense(256, activation='relu'))  # Increased neurons
cnn_model.add(BatchNormalization())
cnn_model.add(Dropout(0.3))  # Slightly reduced dropout rate
cnn_model.add(Dense(1, activation='sigmoid'))

# Compile the model
cnn_model.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])  # Reduced learning rate

# Early stopping and learning rate scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# Train the model
history = cnn_model.fit(
    X_train_cnn,
    y_train_balanced,
    validation_data=(X_val_cnn, y_val),
    epochs=30,  # Increased epochs for better training
    batch_size=64,  # Smaller batch size
    verbose=1,
    callbacks=[early_stopping, lr_scheduler]
)

# Evaluate on Test Set
cnn_pred = (cnn_model.predict(X_test_cnn) > 0.5).astype("int32")
print("\nCNN Model Evaluation:")

# Evaluation Metrics
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def plot_roc_curve(y_true, y_pred, model_name):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Receiver Operating Characteristic - {model_name}')
    plt.legend(loc="lower right")
    plt.show()

def print_metrics(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    print(f"{model_name} - Accuracy: {accuracy:.4f}")
    print(f"\nClassification Report for {model_name}:\n{classification_report(y_true, y_pred)}")
    plot_confusion_matrix(y_true, y_pred, model_name)
    plot_roc_curve(y_true, y_pred, model_name)

print_metrics(y_test, cnn_pred, "CNN")
# Out:
# Starting CNN Training...
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 214s 22ms/step - accuracy: 0.6081 - loss: 0.6797 - val_accuracy: 0.5027 - val_loss: 10.6657 - learning_rate: 5.0000e-04
# Epoch 2/30
#  173/9820 ━━━━━━━━━━━━━━━━━━━━ 2:57 18ms/step - accuracy: 0.6429 - loss: 0.6428[CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  23.9s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  20.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=150; total time=  38.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=150; total time=  41.5s
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=250; total time= 5.7min
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=250; total time= 5.8min
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=500; total time=11.8min
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=300; total time=   8.2s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=300; total time=   6.9s
#  197/9820 ━━━━━━━━━━━━━━━━━━━━ 2:59 19ms/step - accuracy: 0.6421 - loss: 0.6435[CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.7s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  29.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=3, n_estimators=200; total time=  57.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=3, n_estimators=200; total time=  29.5s
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=250; total time= 5.7min
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=250; total time= 5.8min
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=500; total time=11.7min
# [CV] END ..learning_rate=0.02, max_depth=3, n_estimators=300; total time=   8.3s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=300; total time=   6.8s
#  357/9820 ━━━━━━━━━━━━━━━━━━━━ 2:59 19ms/step - accuracy: 0.6411 - loss: 0.6456[CV] END ..learning_rate=0.02, max_depth=3, n_estimators=500; total time=  11.8s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=300; total time=   6.4s
#  371/9820 ━━━━━━━━━━━━━━━━━━━━ 3:00 19ms/step - accuracy: 0.6411 - loss: 0.6456[CV] END ..learning_rate=0.02, max_depth=3, n_estimators=500; total time=  12.0s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=300; total time=   6.5s
#  385/9820 ━━━━━━━━━━━━━━━━━━━━ 3:01 19ms/step - accuracy: 0.6411 - loss: 0.6457[CV] END ..learning_rate=0.02, max_depth=5, n_estimators=300; total time=  10.3s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=500; total time=   8.6s
#  394/9820 ━━━━━━━━━━━━━━━━━━━━ 3:01 19ms/step - accuracy: 0.6412 - loss: 0.6457[CV] END ..learning_rate=0.02, max_depth=5, n_estimators=300; total time=  10.0s
# [CV] END ...learning_rate=0.3, max_depth=3, n_estimators=500; total time=   8.8s
#  558/9820 ━━━━━━━━━━━━━━━━━━━━ 2:58 19ms/step - accuracy: 0.6414 - loss: 0.6459[CV] END ..learning_rate=0.02, max_depth=5, n_estimators=500; total time=  14.4s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=500; total time=   7.8s
#  563/9820 ━━━━━━━━━━━━━━━━━━━━ 2:58 19ms/step - accuracy: 0.6414 - loss: 0.6459[CV] END ..learning_rate=0.02, max_depth=5, n_estimators=500; total time=  14.3s
# [CV] END ...learning_rate=0.3, max_depth=5, n_estimators=500; total time=   7.9s
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 205s 21ms/step - accuracy: 0.6444 - loss: 0.6449 - val_accuracy: 0.5027 - val_loss: 70.0512 - learning_rate: 5.0000e-04
# Epoch 3/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 217s 22ms/step - accuracy: 0.6467 - loss: 0.6417 - val_accuracy: 0.5801 - val_loss: 0.6707 - learning_rate: 5.0000e-04
# Epoch 4/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 204s 21ms/step - accuracy: 0.6456 - loss: 0.6421 - val_accuracy: 0.5027 - val_loss: 69.3178 - learning_rate: 5.0000e-04
# Epoch 5/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 210s 21ms/step - accuracy: 0.6461 - loss: 0.6415 - val_accuracy: 0.5205 - val_loss: 0.7771 - learning_rate: 5.0000e-04
# Epoch 6/30
# 9818/9820 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6474 - loss: 0.6400
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 212s 22ms/step - accuracy: 0.6474 - loss: 0.6400 - val_accuracy: 0.5029 - val_loss: 2.6152 - learning_rate: 5.0000e-04
# Epoch 7/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 212s 22ms/step - accuracy: 0.6483 - loss: 0.6391 - val_accuracy: 0.5027 - val_loss: 121.7450 - learning_rate: 2.5000e-04
# Epoch 8/30
# 9820/9820 ━━━━━━━━━━━━━━━━━━━━ 202s 21ms/step - accuracy: 0.6472 - loss: 0.6390 - val_accuracy: 0.5029 - val_loss: 9.2753 - learning_rate: 2.5000e-04
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 4199/4199 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step
#
# CNN Model Evaluation:
# CNN - Accuracy: 0.5782
#
# Classification Report for CNN:
#               precision    recall  f1-score   support
#
#            0       0.55      0.93      0.69     67072
#            1       0.76      0.23      0.35     67281
#
#     accuracy                           0.58    134353
#    macro avg       0.65      0.58      0.52    134353
# weighted avg       0.65      0.58      0.52    134353

# %%
# Define the models and their predictions
models = {
    "Random Forest": rf_best,
    "Gradient Boosting": gb_best,
    "XGBoost": xgb_best,
    "Neural Network": nn_model,
    "CNN": cnn_model
}

# Compute the accuracy for all models
model_accuracies = {
    "Random Forest": accuracy_score(y_test_subset, rf_pred),
    "Gradient Boosting": accuracy_score(y_test_subset, gb_pred),
    "XGBoost": accuracy_score(y_test_subset, xgb_pred),
    "Neural Network": accuracy_score(y_test, nn_pred),
    "CNN": accuracy_score(y_test, cnn_pred)
}

# Print the metrics for all models
print("\nModel Performance:")
for model_name, accuracy in model_accuracies.items():
    print(f"{model_name} - Accuracy: {accuracy:.4f}")

# Find the best model based on accuracy
best_model_name = max(model_accuracies, key=model_accuracies.get)
best_model_accuracy = model_accuracies[best_model_name]
print(f"\nBest Model for the Dataset: {best_model_name} with Accuracy: {best_model_accuracy:.4f}")

# Plot the accuracy of all models
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(model_accuracies.keys(), model_accuracies.values(), color='skyblue')
plt.ylabel('Accuracy')
plt.title('Model Comparison Based on Accuracy')
plt.xticks(rotation=45)
plt.show()

# Save the best model
import joblib

best_model = models[best_model_name]
if best_model_name in ["Random Forest", "Gradient Boosting", "XGBoost"]:
    joblib.dump(best_model, f"{best_model_name}_model.pkl")
    print(f"\nBest model ({best_model_name}) saved as {best_model_name}_model.pkl")
elif best_model_name in ["Neural Network", "CNN"]:
    best_model.save(f"{best_model_name}_model.h5")
    print(f"\nBest model ({best_model_name}) saved as {best_model_name}_model.h5")
# Out:
# Model Performance:
# Random Forest - Accuracy: 0.6473
# Gradient Boosting - Accuracy: 0.6471
# XGBoost - Accuracy: 0.6474
# Neural Network - Accuracy: 0.5022
# CNN - Accuracy: 0.5782
#
# Best Model for the Dataset: XGBoost with Accuracy: 0.6474
# Best model (XGBoost) saved as XGBoost_model.pkl
